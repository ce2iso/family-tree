# %% [markdown]
# <a href="https://colab.research.google.com/github/ce2iso/family-tree/blob/main/1_mp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安裝 Whisper 模型
# !pip install --upgrade pip
# !pip install git+https://github.com/openai/whisper.git

# 上傳語音檔
from google.colab import files
audio = files.upload()  # 例如上傳 test_audio.mp3

# 載入模型並轉錄
import whisper
model = whisper.load_model("small")
for fn in audio.keys():
    result = model.transcribe(fn, language="zh")
    # 輸出逐字稿
    with open("output.txt", "w", encoding="utf-8") as f:
        f.write(result["text"])
    # 輸出字幕檔
    whisper.utils.write_srt(result["segments"], "output.srt")

# 下載檔案
files.download("output.txt")
files.download("output.srt")
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-nkvl1h7_
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-nkvl1h7_
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      <input type="file" id="files-f9cfd6bf-7fcc-46ed-bf9c-af05e1f2724c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f9cfd6bf-7fcc-46ed-bf9c-af05e1f2724c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# ...

# %% [markdown]
# # 新增區段
